# %%
import pandas as pd
import numpy as np

draft1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")
draft1.head(5)
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
# Question 1: To Delete Unnamed Column
draft1.columns.values        ##To check the column names to get an idea of unnamed columns.
# Out:
# array(['Unnamed: 0', 'Id', 'Name', 'Year', 'Gender', 'State', 'Count'],
#       dtype=object)

# %%
##In the given dataset, there is 1 unnamed column, we will now locate and delete the unnamed column

draft1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv", index_col=0)
print("\nData after removing unnamed column \n", "-"*40, sep='')
draft2 = draft1.loc[:, ~draft1.columns.str.contains('^Unnamed')]
draft2.head(5)
# Out:
# Data after removing unnamed column
# ----------------------------------------
# C:\Users\navne\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#           Id     Name  Year Gender State  Count
# 11349  11350     Emma  2004      F    AK     62
# 11350  11351  Madison  2004      F    AK     48
# 11351  11352   Hannah  2004      F    AK     46
# 11352  11353    Grace  2004      F    AK     44
# 11353  11354    Emily  2004      F    AK     41

# %%
#Question 2: distribution of male and female
draft1.Gender.value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
#Question 3: Top 5 most preffered names

print("\nTop 5 most preffered names \n", "-"*30, sep='')
pref_name = draft1.Name.value_counts()
pref_name.head(5)
# Out:
# Top 5 most preffered names
# ------------------------------
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
#Question 4: To find the median name occurrence in the dataset

print("\n Median name occurrence in the dataset is:",pref_name.median())
# Out:
#  Median name occurrence in the dataset is: 8.0

# %%
#Question 5: Distribution of male and female born count by states

pd.crosstab(draft1.State, draft1.Gender)
# Out:
# Gender      F      M
# State
# AK       2404   2587
# AL       9878   8419
# AR       7171   6475
# AZ      14518  10820
# CA      45144  31637
# CO      11424   9183
# CT       6575   5733
# DC       3053   3000
# DE       2549   2440
# FL      25781  20070
# GA      19385  15454
# HI       3255   3546
# IA       7131   6307
# ID       4918   4833
# IL      21268  16828
# IN      13056  10613
# KS       7753   6748
# KY       8817   7267
# LA      10510   9676
# MA      10580   8609
# MD      11276   9483
# ME       2976   2777
# MI      16038  13243
# MN      10677   9004
# MO      11948   9917
# MS       7235   6862
# MT       2690   2986
# NC      17357  13530
# ND       2399   2581
# NE       5370   5029
# NH       2957   2659
# NJ      15041  12274
# NM       5721   4966
# NV       7092   6024
# NY      28158  22585
# OH      18143  14318
# OK       9519   8138
# OR       8604   7333
# PA      17480  14171
# RI       2558   2468
# SC       9465   8195
# SD       2838   2908
# ...
